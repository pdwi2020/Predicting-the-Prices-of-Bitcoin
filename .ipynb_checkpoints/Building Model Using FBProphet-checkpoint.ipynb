# %% [markdown]
# ### Forecasting Using Prophet

# %%
from fbprophet import Prophet

# %%
data.head()
# Out:
#                Open     High      Low    Close         Volume      Market Cap  \
# Date
# 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000  45,535,800,000
# 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000  44,890,700,000
# 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000  46,246,700,000
# 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000  44,144,400,000
# 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000  41,816,500,000
#
#             dayofweek  prediction_naive
# Date
# 2017-07-31   weekdays               NaN
# 2017-07-30  weeekends           2875.34
# 2017-07-29  weeekends           2757.18
# 2017-07-28   weekdays           2726.45
# 2017-07-27   weekdays           2809.01

# %%
df=data[['Close']]

# %%
df.tail()
# Out:
#              Close
# Date
# 2013-05-02  105.21
# 2013-05-01  116.99
# 2013-04-30  139.00
# 2013-04-29  144.54
# 2013-04-28  134.21

# %%
df=df.reset_index()

# %%
df.columns=['ds','y']

# %%
df.head()
# Out:
#           ds        y
# 0 2017-07-31  2875.34
# 1 2017-07-30  2757.18
# 2 2017-07-29  2726.45
# 3 2017-07-28  2809.01
# 4 2017-07-27  2671.78

# %%
model= Prophet()
model.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods=500, freq='D')
forecast = model.predict(future)

# %%
###prediction-basically means for this value, we have this value ie for that day
###whereas forecasting is all about showing some trend ie for a year
### we can predict covid-19 cases using prophet as well

# %%
### now do Prediction on future_dates
forecast
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0    2013-04-28    78.013914  -216.468548    53.078971    78.013914
# 1    2013-04-29    76.042304  -198.166975    65.826284    76.042304
# 2    2013-04-30    74.070694  -181.947361    91.726343    74.070694
# 3    2013-05-01    72.099083  -201.127627    91.433331    72.099083
# 4    2013-05-02    70.127473  -197.084181    85.888042    70.127473
# ...         ...          ...          ...          ...          ...
# 2051 2018-12-09  5557.449261  2951.010509  8160.248396  2871.024226
# 2052 2018-12-10  5563.872450  2915.273741  8139.489085  2868.356825
# 2053 2018-12-11  5570.295639  2945.730250  8138.608862  2865.689423
# 2054 2018-12-12  5576.718828  2864.793784  8123.848562  2863.022022
# 2055 2018-12-13  5583.142017  2905.339257  8162.819751  2860.354620
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0       78.013914     -154.730349           -154.730349           -154.730349
# 1       76.042304     -144.214701           -144.214701           -144.214701
# 2       74.070694     -136.941412           -136.941412           -136.941412
# 3       72.099083     -133.029361           -133.029361           -133.029361
# 4       70.127473     -124.550376           -124.550376           -124.550376
# ...           ...             ...                   ...                   ...
# 2051  8112.361641       29.400894             29.400894             29.400894
# 2052  8124.664358       27.024700             27.024700             27.024700
# 2053  8136.967075       21.252516             21.252516             21.252516
# 2054  8149.269792       12.030070             12.030070             12.030070
# 2055  8161.572509        7.342910              7.342910              7.342910
#
#         weekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# 0    -2.728693     -2.728693     -2.728693 -152.001656   -152.001656
# 1     1.480335      1.480335      1.480335 -145.695036   -145.695036
# 2     2.455150      2.455150      2.455150 -139.396562   -139.396562
# 3     0.053955      0.053955      0.053955 -133.083316   -133.083316
# 4     2.178101      2.178101      2.178101 -126.728477   -126.728477
# ...        ...           ...           ...         ...           ...
# 2051 -2.728693     -2.728693     -2.728693   32.129587     32.129587
# 2052  1.480335      1.480335      1.480335   25.544365     25.544365
# 2053  2.455150      2.455150      2.455150   18.797366     18.797366
# 2054  0.053955      0.053955      0.053955   11.976115     11.976115
# 2055  2.178101      2.178101      2.178101    5.164808      5.164808
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0      -152.001656                   0.0                         0.0
# 1      -145.695036                   0.0                         0.0
# 2      -139.396562                   0.0                         0.0
# 3      -133.083316                   0.0                         0.0
# 4      -126.728477                   0.0                         0.0
# ...            ...                   ...                         ...
# 2051     32.129587                   0.0                         0.0
# 2052     25.544365                   0.0                         0.0
# 2053     18.797366                   0.0                         0.0
# 2054     11.976115                   0.0                         0.0
# 2055      5.164808                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 0                            0.0   -76.716435
# 1                            0.0   -68.172397
# 2                            0.0   -62.870719
# 3                            0.0   -60.930278
# 4                            0.0   -54.422903
# ...                          ...          ...
# 2051                         0.0  5586.850155
# 2052                         0.0  5590.897150
# 2053                         0.0  5591.548155
# 2054                         0.0  5588.748898
# 2055                         0.0  5590.484927
#
# [2056 rows x 19 columns]

# %%
##yhat=(yhat_lower+yhat_upper)/2
##(-223+69)/2

# %%
### to show last 5 entries
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 2051 2018-12-09  5586.850155  2951.010509  8160.248396
# 2052 2018-12-10  5590.897150  2915.273741  8139.489085
# 2053 2018-12-11  5591.548155  2945.730250  8138.608862
# 2054 2018-12-12  5588.748898  2864.793784  8123.848562
# 2055 2018-12-13  5590.484927  2905.339257  8162.819751

# %% [markdown]
# #### Plotting the Forecasts in fb Prophet
#
#     Prophet has an inbuilt function that enables us to plot the forecasts we just generated.
#     This is achieved using model.plot() and passing in our forecasts as the argument.
#     The blue line in the graph represents the predicted values while the black dots represents the data in our dataset.

# %%
#### plot the predictions u will see these are with respect to yhat
model.plot(forecast)

# %%
## The dark blue line in the graph represents the predicted values while the black dots represents the data in our dataset
### whereas light blue lines basically shows some trend

# %%
##### Lets Visualize Each Components[Trends,Weekly]
model.plot_components(forecast)
